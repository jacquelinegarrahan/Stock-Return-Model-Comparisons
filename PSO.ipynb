# %%
import  pandas as pd
import numpy as np

# %%
df = pd.read_csv("files/sp_500.csv")
period = 5

# %%
df['log_ret'] = (252/period) * ( np.log(df.Close) - np.log(df.Close.shift(period)))
# drop  na values
df = df.dropna()
df = df.reset_index()
df
# Out:
#       index        Date         Open         High          Low        Close  \
# 0         5  2007-11-20  1434.510010  1452.640015  1419.280029  1439.699951
# 1         6  2007-11-21  1434.709961  1436.400024  1415.640015  1416.770020
# 2         7  2007-11-23  1417.619995  1440.859985  1417.619995  1440.699951
# 3         8  2007-11-26  1440.739990  1446.089966  1406.099976  1407.219971
# 4         9  2007-11-27  1409.589966  1429.489990  1407.430054  1428.229980
# ...     ...         ...          ...          ...          ...          ...
# 2760   2765  2018-11-06  2738.399902  2756.820068  2737.080078  2755.449951
# 2761   2766  2018-11-07  2774.129883  2815.149902  2774.129883  2813.889893
# 2762   2767  2018-11-08  2806.379883  2814.750000  2794.989990  2806.830078
# 2763   2768  2018-11-09  2794.100098  2794.100098  2764.239990  2781.010010
# 2764   2769  2018-11-12  2773.929932  2775.989990  2722.000000  2726.219971
#
#         Adj Close      Volume   log_ret
# ...

# %%
from optimization.run_search import run_search, PARAMETER_RANGES

# %%
model = "GBM-mod"
runtime = 50

best_score, best_options = run_search(df.log_ret, PARAMETER_RANGES[model], runtime, model, search="pso")
# Out:
# 2020-06-15 22:26:39,641 - pyswarms.single.global_best - INFO - Optimize for 1000 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best:   0%|          |0/1000/Users/jacquelinegarrahan/opt/anaconda3/envs/stock-return-model-comparison/lib/python3.7/site-packages/sdeint/wiener.py:67: RuntimeWarning: divide by zero encountered in double_scalars
#   sqrt2h = np.sqrt(2.0/h)
# /Users/jacquelinegarrahan/opt/anaconda3/envs/stock-return-model-comparison/lib/python3.7/site-packages/sdeint/wiener.py:70: RuntimeWarning: invalid value encountered in multiply
#   term1 = _dot(Xk, _t(Yk + sqrt2h*dW))
# /Users/jacquelinegarrahan/opt/anaconda3/envs/stock-return-model-comparison/lib/python3.7/site-packages/sdeint/wiener.py:71: RuntimeWarning: invalid value encountered in multiply
#   term2 = _dot(Yk + sqrt2h*dW, _t(Xk))
# /Users/jacquelinegarrahan/dev/stock-return-model-comparisons/models/gbm_mod.py:27: RuntimeWarning: overflow encountered in exp
# ...

# %%
PARAMETER_RANGES[model].values()
